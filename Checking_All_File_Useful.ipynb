# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import glob
import os

# %%
files = glob.glob('../Image_2048/*/*.png')
# files
# Out:
# ['../Image_2048/41463/1605327403.png',
#  '../Image_2048/41463/1204850506.png',
#  '../Image_2048/41463/862791945.png',
#  '../Image_2048/41463/1782615863.png',
#  '../Image_2048/41692/148740033.png',
#  '../Image_2048/41692/734284346.png',
#  '../Image_2048/41692/1554100543.png',
#  '../Image_2048/41692/1437715281.png',
#  '../Image_2048/4049/810506537.png',
#  '../Image_2048/4049/2024905683.png',
#  '../Image_2048/4049/1489915156.png',
#  '../Image_2048/4049/1374539578.png',
#  '../Image_2048/58675/1019795906.png',
#  '../Image_2048/58675/1217706264.png',
#  '../Image_2048/58675/2085700898.png',
#  '../Image_2048/58675/1343810360.png',
#  '../Image_2048/45461/528898470.png',
#  '../Image_2048/45461/1325808274.png',
#  '../Image_2048/45461/1474211061.png',
#  '../Image_2048/45461/450222065.png',
#  '../Image_2048/45461/1788790964.png',
#  '../Image_2048/45461/980328348.png',
#  '../Image_2048/41238/899283143.png',
#  '../Image_2048/41238/1152046649.png',
# ...

# %%
im = []

for item in files:
    # reading png image file
    # np.append(im,img.imread(item))
    im.append(os.path.getsize(item))

# %%
plt.hist(im)
plt.show()
